# %%
from tradepy.data.loader import load_future
from tradepy.data.eda import plot_cleaning
from tradepy.data.cleaner import add_trading_date_by_gap
from tradepy.config.config import load_symbols

# %%
symbols = load_symbols()

# %%
symbols
# Out:
# ['AD',
#  'BP',
#  'CL',
#  'EC',
#  'ES',
#  'GC',
#  'MFXI',
#  'NG',
#  'NQ',
#  'YM',
#  'ZB',
#  'ZN',
#  'ZS']

# %%
symbol = symbols[4]

# %%
df, spec = load_future(symbol)

# %%
df = add_trading_date_by_gap(df)

# %%
df
# Out:
#         ticker per       date      time     open     high      low    close  \
# 0           ES   I 1997-09-10  07:08:00   934.00   934.00   934.00   934.00
# 1           ES   I 1997-09-10  07:15:00   933.75   933.75   933.75   933.75
# 2           ES   I 1997-09-10  08:10:00   933.75   933.75   933.75   933.75
# 3           ES   I 1997-09-10  08:13:00   934.00   934.00   934.00   934.00
# 4           ES   I 1997-09-10  08:20:00   933.75   933.75   933.75   933.75
# ...        ...  ..        ...       ...      ...      ...      ...      ...
# 8631144     ES   I 2026-01-19  06:57:00  6917.00  6917.00  6916.75  6916.75
# 8631145     ES   I 2026-01-19  06:58:00  6917.00  6917.00  6916.75  6917.00
# 8631146     ES   I 2026-01-19  06:59:00  6917.00  6917.50  6916.75  6916.75
# 8631147     ES   I 2026-01-19  07:00:00  6916.75  6917.00  6916.25  6916.75
# 8631148     ES   I 2026-01-19  07:01:00  6916.75  6917.25  6916.50  6917.00
#
#          volume  openint            datetime  session_id trading_date
# 0             1        0 1997-09-10 07:08:00           0   1997-09-10
# 1             1        0 1997-09-10 07:15:00           0   1997-09-10
# 2             1        0 1997-09-10 08:10:00           0   1997-09-10
# 3             1        0 1997-09-10 08:13:00           0   1997-09-10
# 4             1        0 1997-09-10 08:20:00           0   1997-09-10
# ...         ...      ...                 ...         ...          ...
# 8631144      26        0 2026-01-19 06:57:00        5073   2026-01-19
# 8631145      33        0 2026-01-19 06:58:00        5073   2026-01-19
# 8631146     112        0 2026-01-19 06:59:00        5073   2026-01-19
# 8631147      64        0 2026-01-19 07:00:00        5073   2026-01-19
# 8631148      33        0 2026-01-19 07:01:00        5073   2026-01-19
#
# [8631149 rows x 13 columns]

# %%
plot_cleaning(df, symbol)
# Out:
# c:\Users\LIJUN\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)
