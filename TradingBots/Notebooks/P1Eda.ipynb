# %%
from tradepy.data.loader import load_future
from tradepy.data.eda import plot_cleaning, plot_comparation_utc
from tradepy.data.cleaner import add_trading_date_by_gap
from tradepy.config.config import load_symbols
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 2
#       1 from tradepy.data.loader import load_future
# ----> 2 from tradepy.data.eda import plot_cleaning, plot_comparation_utc
#       3 from tradepy.data.cleaner import add_trading_date_by_gap
#       4 from tradepy.config.config import load_symbols
#
# File E:\Futuro\MLAlgoTrading\TradingBots\tradepy\tradepy\data\eda.py:285
#     281     else:
#     282         plt.close(fig)
#     284 def plot_comparation_utc(
# --> 285     df: pd.Dataframe,
#     286     ticker: str = "Future",
#     287     show: bool = True,
#     288     save: bool = False,
#     289 ) -> None:
#     291     d = _prep(df)
#     293     fig = plt.figure(figsize=(18, 28))
#
# AttributeError: module 'pandas' has no attribute 'Dataframe'

# %%
symbols = load_symbols()

# %%
symbols
# Out:
# ['AD',
#  'BP',
#  'CL',
#  'EC',
#  'ES',
#  'GC',
#  'MFXI',
#  'NG',
#  'NQ',
#  'YM',
#  'ZB',
#  'ZN',
#  'ZS']

# %%
symbol = symbols[8]

# %%
df, spec = load_future(symbol)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 7861986 entries, 0 to 7861985
# Data columns (total 12 columns):
#  #   Column        Dtype
# ---  ------        -----
#  0   ticker        str
#  1   per           str
#  2   date          datetime64[us]
#  3   time          object
#  4   open          float64
#  5   high          float64
#  6   low           float64
#  7   close         float64
#  8   volume        int64
#  9   openint       int64
#  10  datetime      datetime64[us]
#  11  datetime_utc  datetime64[us]
# dtypes: datetime64[us](3), float64(4), int64(2), object(1), str(2)
# memory usage: 742.3+ MB

# %%
df = add_trading_date_by_gap(df)

# %%
df
# Out:
#         ticker per       date      time      open      high       low  \
# 0           NQ   I 1996-04-10  16:02:00    622.00    622.00    622.00
# 1           NQ   I 1996-04-10  16:03:00    621.80    621.80    621.80
# 2           NQ   I 1996-04-10  16:04:00    621.80    622.00    621.80
# 3           NQ   I 1996-04-10  16:05:00    621.50    621.80    621.50
# 4           NQ   I 1996-04-10  16:07:00    621.75    621.75    621.60
# ...        ...  ..        ...       ...       ...       ...       ...
# 7861981     NQ   I 2026-01-19  06:57:00  25397.25  25398.50  25396.50
# 7861982     NQ   I 2026-01-19  06:58:00  25396.50  25397.50  25395.75
# 7861983     NQ   I 2026-01-19  06:59:00  25397.00  25398.25  25393.00
# 7861984     NQ   I 2026-01-19  07:00:00  25395.00  25395.50  25393.00
# 7861985     NQ   I 2026-01-19  07:01:00  25393.25  25397.50  25392.50
#
#             close  volume  openint            datetime        datetime_utc  \
# ...

# %%
plot_cleaning(df, symbol)
# Out:
# c:\Users\LIJUN\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
df["datetime"] = df["datetime_utc"]
plot_comparation_utc(df, symbol)
# Out:
# c:\Users\LIJUN\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)
